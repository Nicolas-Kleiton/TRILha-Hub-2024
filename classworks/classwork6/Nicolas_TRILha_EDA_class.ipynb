# %% [markdown]
# # EDA na prática! 😎

# %% [markdown]
# ### **Descrição:**
# Agora que você já sabe os básicos do por quê precisamos de dados limpos, bem estruturados e como trabalhar com um conjunto de dados até chegar nessa etapa, que tal testar as nossas novas habilidades em um dataset real? Hoje, o nosso objetivo será limpar e extrair alguns insights do conjunto de dados da tragédia mais esquisita do mundo das navegações, o [Titanic](https://www.kaggle.com/c/titanic/overview)! Esse dataset vai incluir as seguintes informações:
#
# |                Coluna                | Descrição |
# |:------------------------------------:|:---------:|
# |                  Survived                 |    Sobrevivência ou não (0 - não; 1- sim)       |
# |                  Pclass                 |    Tipo de passagem (1a, 2a ou 3a classe)    |
# |          SibSp   |    No. de irmãos/cônjuges a bordo do Titanic       |
# | Parch |    No. de pais/filhos a bordo do Titanic       |
# |      Ticket   |      No. do tíquete    |
# |       Fare       |    Tarifa de passageiro       |
# |                Cabin               |       Número da cabine    |
# |    Embarked  |      Porto de embarcação (C - Cherbourg, Q - Queenstown, S - Southampton)     |
#
#
# Essa próxima etapa deve deixar algumas pessoas com frio na barriga, mas relaxa que temos tempo mais que suficiente para explorar esses dados.
# #### Ps: Esse é muito melhor de entender do que o dos cachorros 😉

# %% [markdown]
# ### 1.1 - Leitura dos dados e realização de descrição estatística
# ---

# %% [markdown]
# A seguir, o dataframe já estará montado pelo método `pd.read_csv()` da biblioteca `pandas`, a partir da execução da célula.
#
# Dica: Você pode acessar a documentação da biblioteca `pandas` [clicando aqui](https://pandas.pydata.org/docs/getting_started/index.html#getting-started). Após o processamento do dataframe, você terá de realizar uma descrição estatística dos dados.
# /
# #### Lembrando! A descrição estatística nada mais é do que mostrar como os valores estão distribuídos, então pode usar quaisquer método achar suficiente para fazer isso, e lembrando, **menos e melhor** é a chave para uma boa análise! 😁

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/IcaroR/TRILha/main/datasets/Titanic/train.csv', sep = ',')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# descrição estatistas
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#informações gerais sobre os dados
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 1.2 - Limpeza dos dados
# ---

# %% [markdown]
# #### Agora que já conseguimos ter uma visão do panorâmica dos dados, conseguimos ver que eles estão uma porcaria, então que tal dar uma faxina neles? Remova todos os erros, como dados faltantes, colunas com tipos errados, etc. Mais uma vez, a leitura da documentação do `pandas` é imprescindível.

# %% [markdown]
# _Sua resposta aqui_

# %%
# Para começar vamos verificar os dados faltantes
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Vamos ver se há elementos duplicados
dataset.duplicated().sum()
# Out:
# 0

# %%
# Criando uma copia do dataset para correção dos dados
df = dataset.copy()

# %%
# Começando com "Age": Irei preencher os faltantes com a mediana das idades invés de excluir-las.
df['Age'].fillna(df['Age'].median(), inplace=True)
# Usei a mediana, pois ela mantém o equilíbrio, diferente da média que poderia ser influenciada por outliers

# Agora que preenchemos as idades, vamos mudar seu tipo para inteiro
df['Age'] = df['Age'].astype(int)

# %%
# Como a coluna "Cabin" tem bastantes valores nulos optei por remove-la.
df = df.drop('Cabin', axis=1)

# %%
# Em "Embarked" existe apenas dois dados faltantes, então podemos excluir as linhas faltantes.
df = df.dropna(subset=['Embarked'])

# %%
# Agora irei excluir dados que são inúteis para a nossa análise:
# PassengerID e ticket serão esses dados que serão removidos
df = dataset.drop(['PassengerId', 'Ticket'], axis=1)

# %%
# Vamos verificar a existência de outliers
# Como podemos ver, a coluna 'Fare' possuem outliers
df[['Fare']].plot.box(figsize=(12, 6), subplots=True, layout=(1, 2), grid=True)
plt.suptitle('Boxplots de Fare', fontsize=14, fontweight='bold')
plt.show()

# %%
# Vamos calcular o intervalo interquartil (IQR) para cada coluna, começando com 'Fare'
Q1_fare = df['Fare'].quantile(0.25)
Q3_fare = df['Fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare

# Definindo os limites para identificar outliers
limite_inferior_fare = Q1_fare - 1.5 * IQR_fare
limite_superior_fare = Q3_fare + 1.5 * IQR_fare

# Removendo os outliers
df = df[(df['Fare'] >= limite_inferior_fare) & (df['Fare'] <= limite_superior_fare)]

# %%
# Vamos verificar como ficou agora:
df.boxplot(column=['Fare'])
plt.show()

# %%
# Vizualização dos dados depois da limpeza
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch     Fare Embarked
# 0      male   22      1      0   7.2500        S
# 1    female   38      1      0  71.2833        C
# 2    female   26      0      0   7.9250        S
# 3    female   35      1      0  53.1000        S
# 4      male   35      0      0   8.0500        S
# ..      ...  ...    ...    ...      ...      ...
# 886    male   27      0      0  13.0000        S
# 887  female   19      0      0  30.0000        S
# 888  female   28      1      2  23.4500        S
# 889    male   26      0      0  30.0000        C
# 890    male   32      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# Verificar novamente os dados faltantes após a limpeza:
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### 1.3 - Análise Exploratória dos Dados
# ---

# %% [markdown]
# #### Ufa! Finalmente demos uma bela limpada naquela bagunça, agora é hora de **REALMENTE** dar uma olhada no que tá acontecendo aqui. A primeira coisa que vamos fazer é procurar algumas correlações e analizar as distribuições das features que estão presentes nesse dataset. Pra fazer isso, recomendo usar a biblioteca `matplotlib.pyplot` para criar gráficos que representem estas medidas. Agora, se você conhecer alguma outra ferramenta que te ajude aqui, pode ir fundo nela!
# Lembrando, use todos os gráficos que achar necessário, mas não precisa exagerar também, beleza?
# Ajude seu monitor! 💀

# %%
# Vamos começar exibindo a matriz de correlação desses dados

# Primeiramente, para isso, vou converter a coluna 'sex' para númerico
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
# Selecionando as colunas relevantes para análise de correlação
colunas_relevantes = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
matriz_correlacao = df[colunas_relevantes].corr()

# Gráfico de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacao, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação')
plt.show()

# %%
# Correlação entre classe social e a sobrevivência

# Vamos agrupar os dois tipos de dados para saber quantas pessoas de cada sexo sobreviveram
sex_survived = dataset.groupby('Sex')['Survived'].sum()
sex = sex_survived.index
survived = sex_survived.values

# %%
# Criando o gráfico em barras
plt.bar(sex, survived, color=['lightpink', 'lightblue'])

# Adicionando título e rótulos
plt.title('Sobrevivência por Sexo')
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Número de Sobreviventes', fontsize=12)

# Exibindo o gráfico
plt.show()

# %%
# Correlação entre a classe social e a sobrevivência

# Agrupando os dados
class_survived = df.groupby('Pclass')['Survived'].sum()
class_ = class_survived.index
survived = class_survived.values

# %%
# Criando o gráfico
plt.bar(class_, survived, color=['lightblue', 'lightsalmon', 'lightcoral'])

# Adicionando título e rótulos
plt.title('Sobrevivência por Classe')
plt.ylabel('Número de Sobreviventes', fontsize=12)
plt.xticks([1, 2, 3], ['1ª Classe', '2ª Classe', '3ª Classe'])

# Exibindo o gráfico
plt.show()

# %%
# Correlação de idade por sobrevivência com o gráfico de violino
sns.violinplot(x='Survived', y='Age', data=df)
plt.title('Distribuição de Idade por Sobrevivência', fontweight="bold")
plt.xlabel('Sobreviveu', fontweight="bold")
plt.ylabel('Idade', fontweight="bold")
plt.show()

# %% [markdown]
# ### 1.4 - Feature Engineering e Dados Categóricos
# ---

# %% [markdown]
# #### 1.4.1 - Sempre que falamos de _Data Science_, já lembramos de tipos diferentes de dados, e com eles, sempre vem os temidos dados categórios. Esse tipo de dados normalmente apresenta uma forma muito diferente de variáveis numéricas, e por consquência, trabalhar com eles tabém exige um cuidado a mais. Por isso, agora vamos transformar alguns desses dados usando os métodos que a gente aprendeu hoje, um deles sendo o OneHotEncoder. Eai, ainda lembra como ele funciona? 🤔
#
# #### Após isso, vamos fazer o _Feature Engineering_! Essa é uma técnica **PODEROSÍSSIMA** que vai ajudar a gente a conseguir algumas outras informações que vimos ser possíveis de extrair no passo `1.3`.
# Agora, basta usar sua intuição e criatividade para decidir como novos atributos podem ser definidos, a partir das informações que já temos.

# %% [markdown]
# Dica: Use as colunas existentes para gerar uma ou mais colunas com atributos distintos dos primeiros.

# %%
# Coluna de faixa etária
df.loc[:, 'Faixa_Etaria'] = pd.cut(df['Age'], bins=[0, 12, 18, 60, 100], labels=['Criança', 'Jovem', 'Adulto', 'Idoso'])

# Coluna de faixa tarifa
df.loc[:, 'Faixa_Tarifa'] = pd.cut(df['Fare'], bins=[0, 10, 30, 100, 1000], labels=['Baixo', 'Medio', 'Alto', 'Muito Alto'])

df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch     Fare Embarked Faixa_Etaria Faixa_Tarifa
# 0      male   22      1      0   7.2500        S       Adulto        Baixo
# 1    female   38      1      0  71.2833        C       Adulto         Alto
# 2    female   26      0      0   7.9250        S       Adulto        Baixo
# 3    female   35      1      0  53.1000        S       Adulto         Alto
# 4      male   35      0      0   8.0500        S       Adulto        Baixo
# ..      ...  ...    ...    ...      ...      ...          ...          ...
# 886    male   27      0      0  13.0000        S       Adulto        Medio
# 887  female   19      0      0  30.0000        S       Adulto        Medio
# 888  female   28      1      2  23.4500        S       Adulto        Medio
# 889    male   26      0      0  30.0000        C       Adulto        Medio
# 890    male   32      0      0   7.7500        Q       Adulto        Baixo
#
# [891 rows x 11 columns]

# %% [markdown]
# 1.4.2 - Em poucos termos, computadores não conseguem entender texto de maneira alguma, mas números, ah, esses as máquinas entendem bem pra caramba!
# Então, que tal usar as técnicas que aprendemos pra deixar tudo necessário em números?

# %% [markdown]
# Dica: Sempre que temos uma feature categórica que possui apenas 2 elementos, podemos transformar ela em uma flag binária!
# Agora o que isso significa eu deixo pra você pesquisar 😉

# %%
# Aplicar One-Hot Encoding para a coluna 'Embarked'

df_encoded = pd.get_dummies(df, columns=['Embarked'], prefix=['Embarked'])

# Exibir o DataFrame resultante
df_encoded
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch     Fare Faixa_Etaria Faixa_Tarifa  Embarked_C  \
# 0      male   22      1      0   7.2500       Adulto        Baixo       False
# 1    female   38      1      0  71.2833       Adulto         Alto        True
# 2    female   26      0      0   7.9250       Adulto        Baixo       False
# 3    female   35      1      0  53.1000       Adulto         Alto       False
# 4      male   35      0      0   8.0500       Adulto        Baixo       False
# ..      ...  ...    ...    ...      ...          ...          ...         ...
# 886    male   27      0      0  13.0000       Adulto        Medio       False
# 887  female   19      0      0  30.0000       Adulto        Medio       False
# 888  female   28      1      2  23.4500       Adulto        Medio       False
# 889    male   26      0      0  30.0000       Adulto        Medio        True
# 890    male   32      0      0   7.7500       Adulto        Baixo       False
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 13 columns]
